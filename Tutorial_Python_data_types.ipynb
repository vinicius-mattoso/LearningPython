# %% [markdown]
# <a href="https://colab.research.google.com/github/vinicius-mattoso/LearningPython/blob/pythonDataTypes/Tutorial_Python_data_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Material para estudo de tipos de dados básicos em python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fonte da imagem: https://www.google.com/imgres?imgurl=https%3A%2F%2Fi.imgur.com%2F6cg2E9Q.png&imgrefurl=https%3A%2F%2Fjovian.ai%2Fsahooashru%2Fpython-variables-and-data-types&tbnid=tPcF_iY-m7YNgM&vet=12ahUKEwixnf6BqZL4AhWtqZUCHUDWD-wQMygQegUIARDpAQ..i&docid=tF4u3frzIk9DPM&w=1920&h=888&q=python%20data%20types&ved=2ahUKEwixnf6BqZL4AhWtqZUCHUDWD-wQMygQegUIARDpAQ

# %% [markdown]
# # Tipos primitivos
#
# Esses são os tipos mais simples de dados que temos na linguagem python. Nesses tipos encontramos números inteiros e decimais, letras, palavras e o tipo "verdadeiro e falso".

# %% [markdown]
# #### Variáveis numéricas
#
# Podem ser divididas entre inteiros ("int") ou fracionários ("float")

# %% [markdown]
# **OBS 01:** Para compreender esse código, vamos introduzir algumas funções.

# %% [markdown]
# ---
# Exibir valores na tela, ou terminal.
#
# ---

# %%
# Vamos fazer o nooso primeiro print
print('Olá Mundo!')
# Out:
# Olá Mundo!

# %% [markdown]
# ---
# Atribuir um valor a uma variavel.
#
# ---

# %%
# Estamos atribuindo o valor de 10 para a variável X
X = 10

# %%
# Exibindo o valor da variavel X
print(X)
# Out:
# 10

# %% [markdown]
# ---
# Saber o tipo de uma variavel.
#
# ---

# %%
# Exibindo o tipo da variavel X
print( type(X) )
# Out:
# <class 'int'>

# %%
#Vamos atribuir uma sequência de variaveis, e depois vamos exibir o tipo de cada uma delas.

x1 = 1/2

x2 = 5
# OBS: para valores fracionados, lembrar que utilizamos o ponto (.) para separa os decimais.
x3 = 1.3
# OBS: para valores complexos, utilizamos o "j" para marcar o valor imaginário
x4 = 1 + 5j

# %%
print( type(x1) )
# Out:
# <class 'float'>

# %%
print( type(x2) )
# Out:
# <class 'int'>

# %%
print( type(x3) )
# Out:
# <class 'float'>

# %%
print( type(x4) )
# Out:
# <class 'complex'>

# %% [markdown]
# #### Variáveis de letras e textos
#
# Letras, palavras ou textos são como tipo "string" (str).
# Para criar uma variavel do tipo string, precisamos colocar o valor entre aspas simples ou aspas dupla.

# %%
# definindo a variavel letra como sendo uma string com a letra a, usando aspas simples.
letra = 'a'

# %%
# exibindo o valor armazenda na variavel letra
print( letra)

# exibindo o tipo da variavel letra
print( type(letra) )
# Out:
# a
# <class 'str'>

# %%
# definindo a variavel letra como sendo uma string com a letra b, usando aspas dupla.
letra = "b"

# %% [markdown]
# **OBS**: como estamos atribuindo novament um valor para a mesma variável, o valor definido anteriormente é esquecido.

# %%
# exibindo o valor armazenda na variavel letra
print( letra)

# exibindo o tipo da variavel letra
print( type(letra) )
# Out:
# b
# <class 'str'>

# %%
print( type(letra) )
# Out:
# <class 'str'>

# %%
# definindo a variavel palavra como sendo uma string com a palavra bola.
palavra = "bola"

# %%
# exibindo o valor armazenda na variavel palavra
print( palavra)

# exibindo o tipo da variavel palavra
print( type(palavra) )
# Out:
# bola
# <class 'str'>

# %% [markdown]
# #### Variáveis de tipo verdadeiro e falso
#
# Variavel do tipo  boleana (bool) é muito comum de ser utilizado associado a estruturas condicionais, que seram explicas em um futuro tutorial.

# %%
X = True

Y = False

# %%
# exibindo o valor armazenda na variavel X e Y
print(X)
print(Y)

# exibindo o tipo da variavel X e Y
print( type(X) )
print( type(Y) )
# Out:
# True
# False
# <class 'bool'>
# <class 'bool'>

# %%
# EXEMPLO DE CÓDIGO COM CONDICIONAL PARA FACILITAR O ENTENDIMENTO

X = True

# Testar o seguinte comando

# X = False

if X == True:
  print("O X é verdadeiro")
else:
  print("O X é falso")
# Out:
# O X é verdadeiro

# %% [markdown]
# # Tipos "Containers"
#
# Essa classificação de "Containers" é só para facilitar no entendimento, uma vez que esses tipos de variaveis que serão apresentadas na sequência possuem um conjunto de variaveis do tipo "primária".
#
# Por exemplo em uma lista, temos uma sequência de palavras. Portanto a lista é uma variavel que podemos classificar como "container".

# %% [markdown]
# ## Variáveis de tipo **LISTA**
#
# Variavel do tipo  Lista, contem uma sequência mutavel dos tipos primitivos de variáveis.

# %%
# Definição de uma lista a uma variavel

#uma lista de números
X = [1, 2, 3, 4, 5]

#uma lista de palavras
Y = ['ana','Pedro',"Bruno"]

#uma lista de variaveis boleanas
Z = [True, False, True]

# %%
# exibindo o valor armazenda na variavel X e Y
print(X)
print(Y)
print(Z)

# exibindo o tipo da variavel X e Y
print( type(X) )
print( type(Y) )
print( type(Z) )
# Out:
# [1, 2, 3, 4, 5]
# ['ana', 'Pedro', 'Bruno']
# [True, False, True]
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %% [markdown]
# ### Pegando um elemento da lista
#
#
# A variavel X é do tipo list, mas e os termos contidos nela?
# Para conseguir identificar o tipo de cada elemento da lista precisamos avaliar sepadaramente esses termos.

# %%
# Pegando o primeiro elemento da lista X
print(X[0])
print('')
# Pegando o ultimo elemento da lista X
print(X[-1])
# Out:
# 1
#
# 5

# %%
# Pegando alguns elemento da lista
print(X[0:2])
# Out:
# [1, 2]

# %% [markdown]
# ### Diferentes tipos de elementos na lista
#
#
# A variavel X é do tipo list, mas todos os elementos precisam ser da mesma classe?

# %%
# Criando uma lista com a combinação de variaveis
X = [1 ,2.2 ,'ana', True ,'Vinicius']
print( type(X) )
# Out:
# <class 'list'>

# %%
print( type(X[0]) )

print( type(X[-1]) )

print( type(X[3]) )
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Se eu quiser pegar apenar um pedaço da lista?
#
# Para fazer isso utilizamos a tecnica de slice

# %%
print('PEGANDO A LISTA INTEIRA:')
print(X[:])
# Out:
# PEGANDO A LISTA INTEIRA:
# [1, 2.2, 'ana', True, 'Vinicius']

# %%
print('PEGANDO ATÉ O 3 ELEMENTO DA LISTA:')
print(X[:2])
# Out:
# PEGANDO ATÉ O 3 ELEMENTO DA LISTA:
# [1, 2.2]

# %% [markdown]
# ATENÇÃO!!!
#
# EM PYTHON COMEÇAMOS A CONTAR DO ZERO, E NÃO DE 1 COMO É FEITO NO MATLAB!!!

# %%
print('PEGANDO OS ULTIMOS 3 ELEMENTOS DA LISTA:')
print(X[-3:])
# Out:
# PEGANDO OS ULTIMOS 3 ELEMENTOS DA LISTA:
# ['ana', True, 'Vinicius']

# %% [markdown]
# ### Somando listas

# %%
Y=['Luccas','Pedro','Matehus']

Z=X+Y

# %%
print(Z)
# Out:
# [1, 2.2, 'ana', True, 'Vinicius', 'Luccas', 'Pedro', 'Matehus']

# %% [markdown]
# ### Replicando listas

# %%
Z=5*X
print(Z)
# Out:
# [1, 2.2, 'ana', True, 'Vinicius', 1, 2.2, 'ana', True, 'Vinicius', 1, 2.2, 'ana', True, 'Vinicius', 1, 2.2, 'ana', True, 'Vinicius', 1, 2.2, 'ana', True, 'Vinicius']

# %% [markdown]
# ## ADICIONANDO ELEMENTOS NA LISA DEPOIS DE CRIADA:
#
# metodos: APPEND() | INSERT() | EXTEND()

# %% [markdown]
# ### Método .append()
#
# Adicionando um elemento ao final da lista

# %%
notas= [8, 5, 10, 2, 4]
print(notas)
# Out:
# [8, 5, 10, 2, 4]

# %%
# Adicionando mais uma nota na lista notas
notas.append(9)

print(notas)
# Out:
# [8, 5, 10, 2, 4, 9]

# %% [markdown]
# Se eu quiser colocar um elemento em uma determinada posição da lista?

# %% [markdown]
# ### Método .insert()
#
# Adicionando elementos em uma determinada posição da lista

# %%
casa=['sala','cozinha','banheiro']
valor = 'quarto'
posicao = 0
casa.insert(posicao, valor)
print(casa)
# Out:
# ['quarto', 'sala', 'cozinha', 'banheiro']

# %%
casa=['sala','cozinha','banheiro']
valor = 'quarto'
posicao = 2
casa.insert(posicao, valor)
print(casa)
# Out:
# ['sala', 'cozinha', 'quarto', 'banheiro']

# %% [markdown]
# ### Método .extend()
#
# Adicionando um conjunto elementos ao final de uma lista

# %%
notas= [8, 5, 10, 2, 4]
print(notas)
# Out:
# [8, 5, 10, 2, 4]

# %%
novas_notas=[10,5,7,6]
notas.extend(novas_notas)
print(notas)
# Out:
# [8, 5, 10, 2, 4, 10, 5, 7, 6]

# %% [markdown]
# O método .append() não serve para esse caso não?

# %%
notas= [8, 5, 10, 2, 4]
notas.append(novas_notas)
print(notas)
# Out:
# [8, 5, 10, 2, 4, [10, 5, 7, 6]]

# %% [markdown]
# ## REMOVENDO ELEMENTOS NA LISA DEPOIS DE CRIADA:
#
# metodos: remove() | pop()

# %% [markdown]
# ### Método .remove()
#
# Removendo um determinado elemento da lista.

# %%
alunos = ['vinicius', 'pedro','lucas', 'matheus', 'ana', 'maria']
print(alunos)
# Out:
# ['vinicius', 'pedro', 'lucas', 'matheus', 'ana', 'maria']

# %%
aluno_removido = 'vinicius'
alunos.remove(aluno_removido)
print(alunos)
# Out:
# ['pedro', 'lucas', 'matheus', 'ana', 'maria']

# %% [markdown]
# Se mando remover uma aluna que não estava na lista inicialmente, o que acontece?

# %%
alunos = ['vinicius', 'pedro','lucas', 'matheus', 'ana', 'maria']
aluno_removido = 'luiza'
alunos.remove(aluno_removido)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-2278366532a8> in <module>()
#       1 alunos = ['vinicius', 'pedro','lucas', 'matheus', 'ana', 'maria']
#       2 aluno_removido = 'luiza'
# ----> 3 alunos.remove(aluno_removido)
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ### Método .pop()
#
# Removendo um determinado elemento da lista por meio do seu index.

# %%
alunos = ['vinicius', 'pedro','lucas', 'matheus', 'ana', 'maria']
print(alunos)
# Out:
# ['vinicius', 'pedro', 'lucas', 'matheus', 'ana', 'maria']

# %%
index = 1
alunos.pop(index)
# Out:
# 'pedro'

# %%
print(alunos)
# Out:
# ['vinicius', 'lucas', 'matheus', 'ana', 'maria']

# %% [markdown]
# ## PROCURANDO UM ELEMENTO NA LISTA

# %% [markdown]
# ### Método .index()
#
# Retorna o index do elemento, se houver, dentro de uma lista.

# %%
alunos = ['vinicius', 'pedro','lucas', 'matheus', 'ana', 'maria']
print(alunos)
# Out:
# ['vinicius', 'pedro', 'lucas', 'matheus', 'ana', 'maria']

# %%
alunos.index('vinicius')
# Out:
# 0

# %%
alunos.index('josé')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-57a241190229> in <module>()
# ----> 1 alunos.index('josé')
#
# ValueError: 'josé' is not in list

# %%
alunos = ['vinicius', 'pedro','lucas', 'matheus', 'ana', 'maria','ana']
print(alunos)
# Out:
# ['vinicius', 'pedro', 'lucas', 'matheus', 'ana', 'maria', 'ana']

# %%
aluno_procurado = 'ana'
resultado = alunos.index(aluno_procurado)
print(resultado)
# Out:
# 4

# %% [markdown]
# Mas quantas Anas eu tenho na minha turma?

# %%
aluno_procurado = 'ana'
resultado = alunos.count(aluno_procurado)
print(resultado)
# Out:
# 2

# %% [markdown]
# ## Variáveis de tipo **TUPLA**
#
# Variavel do tipo  Tupla, contem uma sequência não mutavel dos tipos primitivos de variáveis.

# %%
minha_primeira_tupla = ('ana', 8,1.5, True, 10)
print(minha_primeira_tupla)
# Out:
# ('ana', 8, 1.5, True, 10)

# %% [markdown]
# ### Método count() para tuplas

# %%
minha_primeira_tupla.count(10)
# Out:
# 1

# %% [markdown]
# ### Método index() para tuplas

# %%
minha_primeira_tupla.index(10)
# Out:
# 4

# %% [markdown]
# Como já mencionado anteriormente, uma tupla é imutavel

# %%
minha_primeira_tupla.append('Vinicius')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-2c6a635f7a61> in <module>()
# ----> 1 minha_primeira_tupla.append('Vinicius')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
Alunos = ('vinicius','pedro','lucas')
Alunas = ('ana','maria','julia')

turma=Alunos+Alunas
print(turma)
# Out:
# ('vinicius', 'pedro', 'lucas', 'ana', 'maria', 'julia')

# %% [markdown]
# ## Variáveis de tipo **Dicionário**
#
# Variavel do tipo  Dicionário, contem uma chave e uma variavel guaradada por essa chave. Essa variavel guardada no dicionário pode ser de qualquer tipo de variavel visto nesse códiogo.

# %%
meu_primeiro_dicionario={
    'chave_0':'Vinicius',
    'chave_1':10,
    'key_0':['vinicius','lucas','luiza'],
    'qqr_coisa':True,
    'test1':(1,2,3,4)
}

# %%
print(meu_primeiro_dicionario)
# Out:
# {'chave_0': 'Vinicius', 'chave_1': 10, 'key_0': ['vinicius', 'lucas', 'luiza'], 'qqr_coisa': True, 'test1': (1, 2, 3, 4)}

# %% [markdown]
# ### Método para pegar as chaves do dicionário
#
# .keys()

# %%
meu_primeiro_dicionario.keys()
# Out:
# dict_keys(['chave_0', 'chave_1', 'key_0', 'qqr_coisa', 'test1'])

# %% [markdown]
# ### Método para pegar os valores do dicionário
#
# .values()

# %%
meu_primeiro_dicionario.values()
# Out:
# dict_values(['Vinicius', 10, ['vinicius', 'lucas', 'luiza'], True, (1, 2, 3, 4)])

# %% [markdown]
# ### Método para pegar um valor do dicionário por meio de uma chave
#
# .get()

# %%
meu_primeiro_dicionario.get('key_0')
# Out:
# ['vinicius', 'lucas', 'luiza']

# %% [markdown]
# ### Método para pegar um valor do dicionário por meio de uma chave
#
# de maneira direta

# %%
meu_primeiro_dicionario['key_0']
# Out:
# ['vinicius', 'lucas', 'luiza']

# %% [markdown]
# ### Método para pegar um valor do dicionário por meio de uma chave
#
# .get()

# %%
meu_primeiro_dicionario.items()
# Out:
# dict_items([('chave_0', 'Vinicius'), ('chave_1', 10), ('key_0', ['vinicius', 'lucas', 'luiza']), ('qqr_coisa', True), ('test1', (1, 2, 3, 4))])

# %%
print(type(meu_primeiro_dicionario.items()))
# Out:
# <class 'dict_items'>

# %%
for key, value in meu_primeiro_dicionario.items():
    print(f'{key} : {value}')
# Out:
# chave_0 : Vinicius
# chave_1 : 10
# key_0 : ['vinicius', 'lucas', 'luiza']
# qqr_coisa : True
# test1 : (1, 2, 3, 4)

# %%
dicionario = {'nome': 'Júlia'}

dicionario['idade'] = 25

print(dicionario)
# Out:
# {'nome': 'Júlia', 'idade': 25}

# %%
dicionario.update({'nome':'Amanda'})

# %%
print(dicionario)
# Out:
# {'nome': 'Amanda', 'idade': 25}

# %%
dicionario.update(tamanho=1.71)
print(dicionario)
# Out:
# {'nome': 'Amanda', 'idade': 25, 'tamanho': 1.71}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fonte da imagem: https://www.google.com/imgres?imgurl=https%3A%2F%2Fmiro.medium.com%2Fmax%2F631%2F1*8J9yViDiXqNYeEWctWkdfQ.jpeg&imgrefurl=https%3A%2F%2Fmedium.com%2Fanalytics-vidhya%2Fdata-types-in-python-506009234f89&tbnid=QyDrdMdPSx8lBM&vet=12ahUKEwixnf6BqZL4AhWtqZUCHUDWD-wQMygBegUIARDLAQ..i&docid=9yfciCs8TBlNiM&w=631&h=486&q=python%20data%20types&ved=2ahUKEwixnf6BqZL4AhWtqZUCHUDWD-wQMygBegUIARDLAQ
