# %% [markdown]
# <a href="https://colab.research.google.com/github/vinicius-mattoso/LearningPython/blob/pythonClasses/Tutorial_Python_Classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classes em Python

# %% [markdown]
#  A utilização de classes auxiliam o processo de organização de dados e funcionalidades de maneira conjunta. Cada classe criada é um novo tipo de objeto, que permite que diversas instânicias do mesmo sejam feitas. Cada instância de uma classe guarda atributos anexados a ela mantendo seu estado.
#
#
#  Documentação base: https://docs.python.org/pt-br/3/tutorial/classes.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# fonte da imagem: https://www.alura.com.br/artigos/poo-programacao-orientada-a-objetos

# %% [markdown]
# ## Criando minha primeira classe

# %%
# Exemplo da classe Carro em Python
class Carro:
    def __init__(self, modelo):
        self.modelo = modelo;
        self.velocidade = 0

    def acelerar(self):
        print('O carro está acelerando')

    def frear(self):
        print('O carro está freiando')

    def acenderFarol(self):
        print('O carro acendeu o farol')

# %% [markdown]
# ### Instanciando minha primeira classe e utilizando os atributos

# %%
polo = Carro(modelo = 'Polo-2.0')

# %%
polo.acelerar()
# Out:
# O carro está acelerando

# %%
polo.frear()
# Out:
# O carro está freiando

# %% [markdown]
# ## Criando uma nova versão da minha classe

# %%
# Exemplo da classe Carro em Python
class Carro:
    def __init__(self, modelo):
        self.modelo = modelo;
        self.velocidade = 0

    def acelerar(self):
        print('O carro está acelerando')

    def frear(self):
        print('O carro está freiando')

    def acenderFarol(self):
        print('O carro acendeu o farol')

    def getModelo(self):
        return self.modelo

    def getCor(self):
        return self.cor

    def setCor(self, cor):
        self.cor = cor

    def getVelocidade(self):
        return self.velocidade

    def setVelocidade(self,velocidade):
        self.velocidade = velocidade

# %% [markdown]
# ### Instanciando a minha classe e utilizando os atributos

# %%
polo = Carro(modelo = 'Polo-2.0')

# %%
polo.getVelocidade()
# Out:
# 0

# %%
polo.acelerar()
# Out:
# O carro está acelerando

# %%
polo.setVelocidade(velocidade=100)

# %%
polo.getVelocidade()
# Out:
# 100

# %%
polo.getCor()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-a875261dc864> in <module>
# ----> 1 polo.getCor()
#
# <ipython-input-5-0cfd3ced876e> in getCor(self)
#      18
#      19     def getCor(self):
# ---> 20         return self.cor
#      21
#      22     def setCor(self, cor):
#
# AttributeError: 'Carro' object has no attribute 'cor'

# %%
polo.setCor('preto')

# %%
polo.getCor()
# Out:
# 'preto'

# %% [markdown]
# ## Criando um conjuntos de instâncias

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# fonte da imagem: https://www.alura.com.br/artigos/poo-programacao-orientada-a-objetos

# %%
polo = Carro(modelo = 'Polo -2.0')

mini = Carro(modelo = 'Mini Cooper -2.0')

beetle = Carro(modelo = 'New beetle -2.0')

# %%
# colocando as cores de cada carro
polo.setCor('preto')
mini.setCor('branco')
beetle.setCor('vermelho')

# %%
frota = [polo, mini, beetle]

# %%
frota[0].getCor()
# Out:
# 'preto'

# %%
frota[1].getCor()
# Out:
# 'branco'

# %%
frota[2].getCor()
# Out:
# 'vermelho'

# %% [markdown]
# ## Conceito de Herança

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# fonte da imagem : https://www.alura.com.br/artigos/poo-programacao-orientada-a-objetos

# %% [markdown]
# A classe filha vai herdar todos os atributos e métodos da classe Pai.
#
# Vamos criar uma classe de carros elétricos que irá herdar tudo da classe carro.

# %%
class Car():
  """Uma tentativa simples de representar um carro."""
  def __init__(self, make, model, year):
        """Inicializa os atributos que descrevem um carro."""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0

  def get_descriptive_name(self):
        """Devolve um nome descritivo, formatado de modo elegante."""
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title()

  def read_odometer(self):
        """Exibe uma frase que mostra a milhagem do carro."""
        print("This car has " + str(self.odometer_reading) + " miles onit.")

  def update_odometer(self, mileage):
        """
        Define o valor de leitura do hodômetro com o valor especificado
        Rejeita a alteração se for tentativa de definir um valor menor
        para o hodômetro
        """
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("You can't roll back an odometer!") 
            
  def increment_odometer(self, miles):
      """
      Soma a quantidade especificada ao valor de leitura do hodômetro.
      """
      self.odometer_reading += miles

# %% [markdown]
# ### Criação da classe filha
#
# OBS: temos que usar o comando " super().__init__() "
#
# Com esse comando estamos inicializando essa classe filha com base na classe pai.

# %%
class ElectricCar(Car):
  """Representa aspectos específicos de veículos elétricos."""
  def __init__(self, make, model, year):
      """Inicializa os atributos da classe-pai."""
      super().__init__(make, model, year)

# %% [markdown]
# ### Podemos utilizar uma atributo da classe pai, mesmo tendo instancaiado uma classe filha. Observe que não houve necessidade de digitar novamente os atributos da classe Pai.

# %%
my_tesla = ElectricCar('tesla', 'model s', 2016)
print(my_tesla.get_descriptive_name())
# Out:
# 2016 Tesla Model S

# %% [markdown]
# ### Adicionando atributos e métodos para diferenciar a classe filha da classe pai

# %%
class ElectricCar(Car):
  """Representa aspectos específicos de veículos elétricos."""
  def __init__(self, make, model, year):
      """Inicializa os atributos da classe-pai.
        Em seguida, inicializa os atributos específicos de um carro elétrico
      """
      super().__init__(make, model, year)
      self.battery_size = 70
      
  def describe_battery(self):
      """Exibe uma frase que descreve a capacidade da bateria."""
      print("This car has a " + str(self.battery_size) + "-kWh battery.")

# %%
my_tesla = ElectricCar('tesla', 'model s', 2016)
my_tesla.describe_battery()
# Out:
# This car has a 70-kWh battery.

# %% [markdown]
# ### Instancias como atributos
#
# Caso perceba que suas classes estão ficando muito específicas para um determinadao assunto, podemos criar outras micro classes que serão instanciadas nas classe mais macro

# %%
class Battery():
    """Uma tentativa simples de modelar uma bateria para um carro elétrico."""
    def __init__(self, battery_size=70):
        """Inicializa os atributos da bateria."""
        self.battery_size = battery_size
    def describe_battery(self):
        """Exibe uma frase que descreve a capacidade da bateria."""
        print("This car has a " + str(self.battery_size) + "-kWh battery.")
    def get_range(self):
        """Exibe uma frase sobre a distância que o carro é capaz de percorrer com essa bateria."""
        if self.battery_size == 70:
            range = 240
        elif self.battery_size == 85:
            range = 270
        message = "This car can go approximately " + str(range)
        message += " miles on a full charge."
        print(message)

# %%
class ElectricCar(Car):
  """Representa aspectos específicos de veículos elétricos."""
  def __init__(self, make, model, year):
      """Inicializa os atributos da classe-pai.
        Em seguida, inicializa os atributos específicos de um carro elétrico
      """
      super().__init__(make, model, year)
      self.battery = Battery()

# %%
my_tesla = ElectricCar('tesla', 'model s', 2016)
my_tesla.battery.describe_battery()
# Out:
# This car has a 70-kWh battery.

# %%
# Dessa forma podemos criar quantas funções específicas da bateria quisermos, sem lotar a classe EletricCar
my_tesla.battery.get_range()
# Out:
# This car can go approximately 240 miles on a full charge.
